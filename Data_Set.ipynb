# %% [markdown]
# <a href="https://colab.research.google.com/github/27nando/Consumer_Insight/blob/main/Data_Set.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
beats = pd.read_csv('/beats_studio_buds_amazon_product_reviews.csv')
beats
# Out:
#                                           Product Name              Name  \
# 0    Beats Studio Buds + | True Wireless Noise Canc...  Matthew Martínez
# 1    Beats Studio Buds + | True Wireless Noise Canc...           Tuck VB
# 2    Beats Studio Buds + | True Wireless Noise Canc...      Rodolfo Leon
# 3    Beats Studio Buds + | True Wireless Noise Canc...             Colin
# 4    Beats Studio Buds + | True Wireless Noise Canc...       Spooky sway
# ..                                                 ...               ...
# 259  Beats Studio Buds + | True Wireless Noise Canc...             Colin
# 260  Beats Studio Buds + | True Wireless Noise Canc...       Spooky sway
# 261  Beats Studio Buds + | True Wireless Noise Canc...              Cody
# 262  Beats Studio Buds + | True Wireless Noise Canc...        chrisshaun
# 263  Beats Studio Buds + | True Wireless Noise Canc...            Don A.
#
#      Stars                                              Title        Date  \
# ...

# %%
bose = pd.read_csv('/bose_quietcomfort_buds_amazon_product_reviews.csv')
bose
# Out:
#                                           Product Name  \
# 0    Bose QuietComfort Earbuds II, Wireless, Blueto...
# 1    Bose QuietComfort Earbuds II, Wireless, Blueto...
# 2    Bose QuietComfort Earbuds II, Wireless, Blueto...
# 3    Bose QuietComfort Earbuds II, Wireless, Blueto...
# 4    Bose QuietComfort Earbuds II, Wireless, Blueto...
# ..                                                 ...
# 299  Bose QuietComfort Earbuds II, Wireless, Blueto...
# 300  Bose QuietComfort Earbuds II, Wireless, Blueto...
# 301  Bose QuietComfort Earbuds II, Wireless, Blueto...
# 302  Bose QuietComfort Earbuds II, Wireless, Blueto...
# 303  Bose QuietComfort Earbuds II, Wireless, Blueto...
#
#                          Name  Stars  \
# 0           Rae & Zoe (Rozae)    5.0
# 1                  Lillyander    5.0
# 2                     ejbleen    1.0
# 3             Kindle Customer    NaN
# 4                 IsaacVale93    NaN
# ..                        ...    ...
# ...

# %%
jbl = pd.read_csv('/jbl_live_pro_buds_amazon_product_reviews.csv')
jbl
# Out:
#                                           Product Name              Name  \
# 0    JBL Live Pro TWS 2: 40 Hours of Playtime, True...       Resume Ryan
# 1    JBL Live Pro TWS 2: 40 Hours of Playtime, True...         waloody88
# 2    JBL Live Pro TWS 2: 40 Hours of Playtime, True...      Garrett Hann
# 3    JBL Live Pro TWS 2: 40 Hours of Playtime, True...  Salvador Garc√≠a
# 4    JBL Live Pro TWS 2: 40 Hours of Playtime, True...     Brendan Brown
# ..                                                 ...               ...
# 251  JBL Live Pro TWS 2: 40 Hours of Playtime, True...  Salvador Garc√≠a
# 252  JBL Live Pro TWS 2: 40 Hours of Playtime, True...     Brendan Brown
# 253  JBL Live Pro TWS 2: 40 Hours of Playtime, True...     Rahul Deodhar
# 254  JBL Live Pro TWS 2: 40 Hours of Playtime, True...          Mohd Ali
# 255  JBL Live Pro TWS 2: 40 Hours of Playtime, True...         Dorian F.
#
#      Stars                                              Title        Date  \
# ...

# %%
senheiser = pd.read_csv('/senheiser_consumer_buds_amazon_product_reviews.csv')
senheiser
# Out:
#                                           Product Name            Name  Stars  \
# 0    Sennheiser Consumer Audio MOMENTUM True Wirele...            Matt    5.0
# 1    Sennheiser Consumer Audio MOMENTUM True Wirele...              LG    1.0
# 2    Sennheiser Consumer Audio MOMENTUM True Wirele...         11eikob    NaN
# 3    Sennheiser Consumer Audio MOMENTUM True Wirele...   Daniela Tozzi    NaN
# 4    Sennheiser Consumer Audio MOMENTUM True Wirele...        Roman E.    NaN
# ..                                                 ...             ...    ...
# 268  Sennheiser Consumer Audio MOMENTUM True Wirele...         11eikob    NaN
# 269  Sennheiser Consumer Audio MOMENTUM True Wirele...   Daniela Tozzi    NaN
# 270  Sennheiser Consumer Audio MOMENTUM True Wirele...        Roman E.    NaN
# 271  Sennheiser Consumer Audio MOMENTUM True Wirele...     CESAR VIANA    NaN
# 272  Sennheiser Consumer Audio MOMENTUM True Wirele...  kim hammerheim    NaN
#
# ...

# %%
sony = pd.read_csv('/sony_link_buds_amazon_product_reviews.csv')
sony
# Out:
#                                           Product Name                  Name  \
# 0    Sony LinkBuds S Truly Wireless Noise Canceling...                    BB
# 1    Sony LinkBuds S Truly Wireless Noise Canceling...                 James
# 2    Sony LinkBuds S Truly Wireless Noise Canceling...                   NaN
# 3    Sony LinkBuds S Truly Wireless Noise Canceling...  Paulo Cesar da Silva
# 4    Sony LinkBuds S Truly Wireless Noise Canceling...            El compras
# ..                                                 ...                   ...
# 324  Sony LinkBuds S Truly Wireless Noise Canceling...                   NaN
# 325  Sony LinkBuds S Truly Wireless Noise Canceling...  Paulo Cesar da Silva
# 326  Sony LinkBuds S Truly Wireless Noise Canceling...            El compras
# 327  Sony LinkBuds S Truly Wireless Noise Canceling...             Bijoy K B
# 328  Sony LinkBuds S Truly Wireless Noise Canceling...                  Tony
#
# ...

# %%
beats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264 entries, 0 to 263
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product Name  264 non-null    object
#  1   Name          264 non-null    object
#  2   Stars         99 non-null     float64
#  3   Title         264 non-null    object
#  4   Date          264 non-null    object
#  5   Description   264 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 12.5+ KB

# %%
bose.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 304 entries, 0 to 303
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product Name  304 non-null    object
#  1   Name          304 non-null    object
#  2   Stars         114 non-null    float64
#  3   Title         304 non-null    object
#  4   Date          304 non-null    object
#  5   Description   304 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 14.4+ KB

# %%
jbl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 256 entries, 0 to 255
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product Name  256 non-null    object
#  1   Name          256 non-null    object
#  2   Stars         96 non-null     float64
#  3   Title         256 non-null    object
#  4   Date          256 non-null    object
#  5   Description   256 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 12.1+ KB

# %%
senheiser.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 273 entries, 0 to 272
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product Name  273 non-null    object
#  1   Name          273 non-null    object
#  2   Stars         78 non-null     float64
#  3   Title         273 non-null    object
#  4   Date          273 non-null    object
#  5   Description   273 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 12.9+ KB

# %%
sony.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 329 entries, 0 to 328
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product Name  329 non-null    object
#  1   Name          282 non-null    object
#  2   Stars         94 non-null     float64
#  3   Title         329 non-null    object
#  4   Date          329 non-null    object
#  5   Description   329 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 15.5+ KB

# %%
updated_beats = beats.dropna()
updated_beats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 99 entries, 0 to 258
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product Name  99 non-null     object
#  1   Name          99 non-null     object
#  2   Stars         99 non-null     float64
#  3   Title         99 non-null     object
#  4   Date          99 non-null     object
#  5   Description   99 non-null     object
# dtypes: float64(1), object(5)
# memory usage: 5.4+ KB

# %%
updated_bose = bose.dropna()
updated_bose.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 114 entries, 0 to 298
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product Name  114 non-null    object
#  1   Name          114 non-null    object
#  2   Stars         114 non-null    float64
#  3   Title         114 non-null    object
#  4   Date          114 non-null    object
#  5   Description   114 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 6.2+ KB

# %%
updated_jbl = jbl.dropna()
updated_jbl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 96 entries, 0 to 250
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product Name  96 non-null     object
#  1   Name          96 non-null     object
#  2   Stars         96 non-null     float64
#  3   Title         96 non-null     object
#  4   Date          96 non-null     object
#  5   Description   96 non-null     object
# dtypes: float64(1), object(5)
# memory usage: 5.2+ KB

# %%
updated_senheiser = senheiser.dropna()
updated_senheiser.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 78 entries, 0 to 267
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product Name  78 non-null     object
#  1   Name          78 non-null     object
#  2   Stars         78 non-null     float64
#  3   Title         78 non-null     object
#  4   Date          78 non-null     object
#  5   Description   78 non-null     object
# dtypes: float64(1), object(5)
# memory usage: 4.3+ KB

# %%
updated_sony = sony.dropna()
updated_sony.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 94 entries, 0 to 323
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product Name  94 non-null     object
#  1   Name          94 non-null     object
#  2   Stars         94 non-null     float64
#  3   Title         94 non-null     object
#  4   Date          94 non-null     object
#  5   Description   94 non-null     object
# dtypes: float64(1), object(5)
# memory usage: 5.1+ KB
